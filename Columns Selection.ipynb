# %%
import pandas as pd
import numpy as np

import pickle

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115676       966    Sri Lanka    Australia  19.3     1                0
# 115677       966    Sri Lanka    Australia  19.4     0                0
# 115678       966    Sri Lanka    Australia  19.5     0      DM de Silva
# 115679       966    Sri Lanka    Australia  19.6     2                0
# 115680       966    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# ...

# %%
df.iloc[5]
# Out:
# match_id                                   1
# batting_team                       Australia
# bowling_team                       Sri Lanka
# ball                                     0.6
# runs                                       3
# player_dismissed                           0
# city                                     NaN
# venue               Melbourne Cricket Ground
# Name: 5, dtype: object

# %%
# # Apne Ko Kya Cahiye 
# Batting Team
# Bowling Team
# Current Run Rate 
# Ground 
# Wickets left
# # Last 5 overs runs scored

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8671
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])  #Logic kya lagaya ki initials jo hai naa sabke ko rakh liya,agar true hua toh woh lag jaayega nahi toh cities

# %%
df['city'] = cities

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115676       966    Sri Lanka    Australia  19.3     1                0
# 115677       966    Sri Lanka    Australia  19.4     0                0
# 115678       966    Sri Lanka    Australia  19.5     0      DM de Silva
# 115679       966    Sri Lanka    Australia  19.6     2                0
# 115680       966    Sri Lanka    Australia  19.7     1                0
#
#              city                     venue
# 0       Melbourne  Melbourne Cricket Ground
# ...

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115676       966    Sri Lanka    Australia  19.3     1                0
# 115677       966    Sri Lanka    Australia  19.4     0                0
# 115678       966    Sri Lanka    Australia  19.5     0      DM de Silva
# 115679       966    Sri Lanka    Australia  19.6     2                0
# 115680       966    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
df['city'].value_counts()
# Out:
# Colombo          4086
# Mirpur           3420
# Johannesburg     3202
# Dubai            3092
# Auckland         2655
#                  ...
# Nairobi           123
# Potchefstroom     122
# Dharamsala        122
# Ahmedabad         121
# Carrara            64
# Name: city, Length: 86, dtype: int64

# %%
df['city'].value_counts()[df['city'].value_counts() > 360]   #Matlab kam se kam 3 match jhan huye ho
# Out:
# Colombo              4086
# Mirpur               3420
# Johannesburg         3202
# Dubai                3092
# Auckland             2655
# Cape Town            2246
# London               2106
# Pallekele            2066
# Barbados             2050
# Sydney               1579
# Melbourne            1574
# Durban               1520
# St Lucia             1487
# Wellington           1350
# Lauderhill           1238
# Hamilton             1219
# Manchester           1144
# Abu Dhabi            1099
# Centurion            1065
# Mumbai                995
# Nottingham            991
# Southampton           987
# Mount Maunganui       938
# Chittagong            868
# Kolkata               844
# Lahore                748
# Delhi                 739
# Nagpur                735
# Cardiff               730
# Chandigarh            627
# Adelaide              623
# Bangalore             620
# St Kitts              618
# Christchurch          614
# Trinidad              611
# ...

# %%
df['city'].value_counts()[df['city'].value_counts() > 360].sum()
# Out:
# 57046

# %%
df['city'].value_counts()[df['city'].value_counts() > 360].shape
# Out:
# (50,)

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 360].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115676       966    Sri Lanka    Australia  19.3     1                0
# 115677       966    Sri Lanka    Australia  19.4     0                0
# 115678       966    Sri Lanka    Australia  19.5     0      DM de Silva
# 115679       966    Sri Lanka    Australia  19.6     2                0
# 115680       966    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\1598928411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115676       966    Sri Lanka    Australia  19.3     1                0
# 115677       966    Sri Lanka    Australia  19.4     0                0
# 115678       966    Sri Lanka    Australia  19.5     0      DM de Silva
# 115679       966    Sri Lanka    Australia  19.6     2                0
# 115680       966    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 0       Melbourne              0
# 1       Melbourne              0
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])                     #Kitna over ka kitna ball
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\1192073022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])                     #Kitna over ka kitna ball
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\1192073022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')     #Kitni deliveries phenk chuke hai
df
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\199961722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')     #Kitni deliveries phenk chuke hai
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)   #Kitne out huye hai
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\478743009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)   #Kitne out huye hai
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\478743009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# ...

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                 0
# 1              1    Australia    Sri Lanka   0.2     0                 0
# 2              1    Australia    Sri Lanka   0.3     1                 0
# 3              1    Australia    Sri Lanka   0.4     2                 0
# 4              1    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115676       966    Sri Lanka    Australia  19.3     1                 8
# 115677       966    Sri Lanka    Australia  19.4     0                 8
# 115678       966    Sri Lanka    Australia  19.5     0                 9
# 115679       966    Sri Lanka    Australia  19.6     2                 9
# 115680       966    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  wickets_left
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']       #Run Rate Nikalne ka Formula
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\4040219610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']       #Run Rate Nikalne ka Formula

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\3055083752.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df                 #Jaahir si baat hai pehle 5 overs mai aise hi hoga
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                 0
# 1              1    Australia    Sri Lanka   0.2     0                 0
# 2              1    Australia    Sri Lanka   0.3     1                 0
# 3              1    Australia    Sri Lanka   0.4     2                 0
# 4              1    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115676       966    Sri Lanka    Australia  19.3     1                 8
# 115677       966    Sri Lanka    Australia  19.4     0                 8
# 115678       966    Sri Lanka    Australia  19.5     0                 9
# 115679       966    Sri Lanka    Australia  19.6     2                 9
# 115680       966    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  wickets_left  \
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\Rishabh-pc\AppData\Local\Temp\ipykernel_2664\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')
final_df
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 57041    Sri Lanka    Australia    Colombo            125           3
# 57042    Sri Lanka    Australia    Colombo            125           2
# 57043    Sri Lanka    Australia    Colombo            125           1
# 57044    Sri Lanka    Australia    Colombo            127           0
# 57045    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# ...

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])         #Shuffle kar diya

# %%
final_df.sample(2)
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 33910   West Indies     Pakistan      St Lucia             91          53
# 47850  South Africa     Pakistan  Johannesburg            135          11
#
#        wickets_left       crr  last_five  runs_x
# 33910             9  8.149254       43.0     150
# 47850             4  7.431193       35.0     153

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#       batting_team bowling_team          city  current_score  balls_left  \
# 55290  Afghanistan  West Indies        Nagpur             38          77
# 20600     Pakistan    Sri Lanka  Johannesburg            136          28
# 22278  New Zealand      England    Manchester             49          71
# 38941  West Indies    Sri Lanka       Colombo            109          16
# 53405      England  West Indies        Mumbai            170           5
# ...            ...          ...           ...            ...         ...
# 38254    Sri Lanka      England     Pallekele             44          84
# 40008  West Indies  New Zealand    Lauderhill             64          70
# 10149  New Zealand        India      Hamilton            135          42
# 39680  West Indies    Australia      Barbados            146          23
# 19497  West Indies      England        London            157          12
#
#        wickets_left        crr  last_five
# 55290             8   5.302326       29.0
# ...

# %%
from sklearn.compose import ColumnTransformer            #yeh strings ko convert karne mai madad karega

# %%
from sklearn.preprocessing import OneHotEncoder          #Transforming categorical data into some numbers or integers

# %%
from sklearn.pipeline import Pipeline                    #A machine learning pipeline is a way to codify and automate the workflow it takes to produce a machine learning model. Machine learning pipelines consist of multiple sequential steps that do everything from data extraction and preprocessing to model training and deployment.

# %%
from sklearn.preprocessing import StandardScaler                #yeh saare normal dependencies liye 
from sklearn.ensemble import RandomForestRegressor                  
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error,accuracy_score

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))        # It is pronounced as R squared and is also known as the coefficient of determination. It works by measuring the amount of variance in the predictions explained by the dataset.
# Out:
# C:\Users\Rishabh-pc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9894509817265719
# 1.576132608897336

# %%
import joblib
joblib.dump(pipe, 'main.joblib')
# Out:
# ['main.joblib']

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Manchester',
#  'Abu Dhabi',
#  'Centurion',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Cardiff',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Christchurch',
#  'Trinidad',
#  'Brisbane',
#  'Hambantota',
#  'Dhaka',
#  'Lucknow',
#  'Kandy',
#  'Karachi',
#  'Birmingham',
#  'Napier',
#  'Hobart',
#  'Rajkot',
#  'Harare',
#  'Perth',
#  'Chester-le-Street',
#  'Bristol',
#  'Pune']
